# %%
import sys
sys.path.append('../src/')

# %%
import pandas as pd

# %%
from trial import db
df = pd.DataFrame(db.data)
df
# Out:
#    dimensions                                   domain  \
# 0           *                                [-32, 32]
# 1           2                                [-32, 32]
# 2           2                                [-32, 32]
# 3           *                                [-35, 35]
# 4           2                                  [-1, 2]
# ..        ...                                      ...
# 57          *                                  [-5, 5]
# 58          *  [-6.283185307179586, 6.283185307179586]
# 59          *                                [-20, 20]
# 60          *                                [-10, 10]
# 61          *                                 [-5, 10]
#
#                                          domain_latex  \
# 0   xi ∈ [-32.768, 32.768], for all i = 1, …, d, a...
# 1                    $x_i \in [-32, 32]$ for $i=1, 2$
# 2                    $x_i \in [-32, 32]$ for $i=1, 2$
# 3               $x_i \in [-35, 35]$ for $i=1, ..., n$
# ...
